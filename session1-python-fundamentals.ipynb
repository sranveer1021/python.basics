# %% [markdown]
# 1.PYTHON OUTPUT

# %%
# python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('Ranveer Singh')
# Out:
# Ranveer Singh

# %%
print(Ranveer Singh)
# Out:
#   Cell In[3], line 1
#     print(Ranveer Singh)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello , 1,2,3,4,True')
# Out:
# Hello , 1,2,3,4,True

# %%
print('Hello',1,2,3,4,True,sep='/')
# Out:
# Hello/1/2/3/4/True

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# 2. Data Types

# %%
#Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/string
print('Hello World')
# Out:
# Hello World

# %%
# Complex Number
print(5+6)
# Out:
# 11

# %%
# list-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Ranveer','gender':'Male','Age':'24'})
# Out:
# {'name': 'Ranveer', 'gender': 'Male', 'Age': '24'}

# %%
# type
type(3)
# Out:
# int

# %% [markdown]
# 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# Stylish declaration techniques

# %%
#C/C++
name = 'ranveer'
print(name)

a = 5
b = 6

print(a+b)
# Out:
# ranveer
# 11

# %%
# Dynamic Typing
a = 5
# Static Typing
int a = 5
# Out:
#   Cell In[28], line 4
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
# Dynamic Binding
a = 5
print(a)
a = 'ranveer'
print(a)

# Static Binding
int a = 5
# Out:
#   Cell In[29], line 8
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# #Comments

# %%
# this is a comment
a = 4
b = 5 # like this
# second comment
print(a+b)
# Out:
# 9

# %% [markdown]
#  4. Keywords & identifies

# %%
# Keywords
keywords is a seperate variable

# %%
# Identifiers
# You can't start with a digit 
name1 = 'ranveer'
print(name1)
# you can use special chars -> _
first_name = 'ranveer'
print(first_name)
# identifiers can not be keywords
# Out:
# ranveer
# ranveer

# %% [markdown]
# 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Email ranveersingh21july@gmail.com
# 'ranveersingh21july@gmail.com'

# %%
# take input from users and store them in a variable
fnum = input('enter first number')
snum = input('enter second number')
# add the 2 variables
result = int(fnum) + int(snum)
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number 7
# enter second number 8
# 15
# <class 'str'>

# %% [markdown]
# 6. Type Conversion

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))
print(4+'4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       2 print(5+5.6)
#       3 print(type(5),type(5.6))
# ----> 4 print(4+'4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
#int(5+4j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310#Octal Literal
d = 0x12c #Hexadecimal Literal

#float Literal
float_1 = 10.5
float_2 = 1.5e2  #1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^3

#Complex Literal
x = 3.14j

print(a,b ,c d)
print(float_1, float_2,float_3)
print(x,x.imag, x.real)

# %%
# binary
c = 0o310
print(1.5e3)
# Out:
# 1500.0

# %%
# complex Literal
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U00001f600\U0001f606\U0001f923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# ὠ0😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
a = None 
print(a)
# Out:
# None

# %% [markdown]
# 8. Operators

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 k
#       2 a = 5
#       3 b = 6
#
# NameError: name 'k' is not defined
