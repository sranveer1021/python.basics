# %%
# Find the length of a given string without using the len() function
s = input('enter the string')

counter = 0

for i in s:
    counter += 1

print('length of string is' ,counter)
# Out:
# enter the string ranveer
# length of string is 7

# %%
# Extract username from a given email.
# Eg if the email is ranveersingh21july@gmail.com
# then the username should be ranveersingh21july

s = input('enter the email')

pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email ranvewre@gmail.com
# ranvewre

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email')
term = input('what would like to search for')

counter = 0
for i in s:
    if i == term:
        counter += 1

print('frequency',counter)
# Out:
# enter the email hi how are you
# what would like to search for o
# frequency 2

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ''

for i in s:
    if i != term:
        result = result + i

    print(result)
# Out:
# enter the string ranveer
# what would like to remove r
# a
# an
# anv
# anve
# anvee
# anvee

# %%
# Write a program that can check whether a given a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
    if s[i] != s[len(s) - i -1]:
        flag = False
        print('Not a palindrome')
        break

    if flag:
        print('palindrome')
# Out:
# enter the string racecar
# palindrome
# palindrome
# palindrome

# %%
# Write a program to count the number of words in a words in a string without split()

s = input('enter the string')
L = []
temp = ''
for i in s:

    if i != ' ':
        temp = temp + i
    else:
        L.append(temp)
        temp = ''
    L.append(temp)
    print(L)
# Out:
# enter the string hi how are oyu
# ['h']
# ['h', 'hi']
# ['h', 'hi', 'hi', '']
# ['h', 'hi', 'hi', '', 'h']
# ['h', 'hi', 'hi', '', 'h', 'ho']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar', 'are']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar', 'are', 'are', '']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar', 'are', 'are', '', 'o']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar', 'are', 'are', '', 'o', 'oy']
# ['h', 'hi', 'hi', '', 'h', 'ho', 'how', 'how', '', 'a', 'ar', 'are', 'are', '', 'o', 'oy', 'oyu']

# %%
# write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
    L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# enter the string hi hOW R PON
# Hi How R Pon

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
    result = digits[number % 10] + result
    number = number//10

print(result)
print(type(result))
# Out:
# enter the number 5654
# 5654
# <class 'str'>
